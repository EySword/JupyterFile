# %%
# %matplotlib qt5
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
matplotlib.pyplot.ion()

# %%
data=pd.read_table('band2.dat',sep='   ',engine='python',names=['K','E'])
data
# Out:
#          K          E
# 0        1 -17.268537
# 1        2 -17.268413
# 2        3 -17.268043
# 3        4 -17.267424
# 4        5 -17.266556
# ...    ...        ...
# 13171  545   3.554124
# 13172  546   3.547277
# 13173  547   3.541990
# 13174  548   3.538270
# 13175  549   3.536137
#
# [13176 rows x 2 columns]

# %%
pd.

# %%
fig=plt.figure()

X=data.K
Y=data.E

# plt.scatter(X,Y,s=0.1)
plt.plot(X,Y,color='red')


# plt.xlim((0,550))
# plt.ylim((-3,3))

plt.show()

# %%
data2 = data.values  # 转为numpy数组
a = int(np.max(data2[:, 0])) # 找K的最大值
num = int(data2.shape[0] / a)  # 循环次数
# print(a, num, data.shape[0])
fig=plt.figure()
for i in range(num):
  X = data2[i*a: (i+1)*a, 0]
  Y = data2[i*a: (i+1)*a, 1]
  plt.plot(X, Y,color='red')
plt.show()

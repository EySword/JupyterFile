# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = h5py.File("kappa5.hdf5",'r')

# %%
g=f['gamma'][30]
g=np.where(g>0,g,-1)
lifetime=np.where(g>0,1.0/(2*2*np.pi*g),0)

# %%
lifetime.shape
# Out:
# (455, 36)

# %%
lifetime_df=pd.DataFrame(lifetime)
fre_df=pd.DataFrame(f['frequency'])

# %%
lifetime_df
# Out:
#             0          1          2          3          4         5   \
# 0     0.000000   0.000000   0.000000   5.917391  11.050556  4.860599
# 1    23.438680  68.017320  45.584663   5.711009  10.683227  9.120663
# 2    17.543663  25.265237  18.527116   5.434580  11.553923  8.208613
# 3    15.887738  13.452861  12.479587   4.313186  10.895847  7.811504
# 4     8.914820  17.662230   5.013059  11.986752  11.566261  7.982560
# ..         ...        ...        ...        ...        ...       ...
# 450   4.084214   4.084214   4.056688   4.056688   9.645981  9.645981
# 451   4.284936   4.284936   4.024126   4.024126   9.337849  9.337849
# 452   4.532046   4.532046   4.283206   4.283206   9.217218  9.217218
# 453   4.580095   4.580095   4.379297   4.379297   8.959584  8.959584
# 454   4.449861   4.449861   4.449861   4.449861   9.342058  9.342058
#
#             6          7         8         9   ...        26        27  \
# ...

# %%
fre_df
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.001505 -0.000345 -0.000327  0.749174  0.918627  1.131592  1.136409
# 1    0.066179  0.091779  0.195179  0.741200  0.911892  1.101786  1.139989
# 2    0.149075  0.181849  0.385517  0.717760  0.891088  1.048806  1.165426
# 3    0.253289  0.268846  0.561528  0.680218  0.856359  1.014290  1.206944
# 4    0.351889  0.371261  0.630572  0.693983  0.824007  0.997973  1.259756
# ..        ...       ...       ...       ...       ...       ...       ...
# 450  1.011878  1.011878  1.106175  1.106175  1.368339  1.368339  1.441528
# 451  1.024961  1.024961  1.099147  1.099147  1.369404  1.369404  1.433204
# 452  1.038554  1.038554  1.089290  1.089290  1.376503  1.376503  1.424543
# 453  1.051707  1.051707  1.077408  1.077408  1.388664  1.388664  1.414685
# 454  1.064638  1.064638  1.064638  1.064638  1.402448  1.402448  1.402448
#
#            7         8         9   ...        26        27        28  \
# ...

# %%
fre.shape
# Out:
# (455, 36)

# %%
# X=np.zeros(455*36, dtype=np.complex_)
# Y_lifetime=np.zeros(455*36, dtype=np.complex_)
X=[0.0*16380]
Y_lifetime=[0.0*16380]

# %%
type(float(lifetime[10][10]))
float(lifetime[10][10])
# Out:
# 1.0628587190690588

# %%
for i in range(455):
    for j in range(36):
        X[i][j]=fre[i][j]
        Y_lifetime[i][j]=lifetime[i][j]
        pass
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-5e83f6180e73> in <module>
#       1 for i in range(455):
#       2     for j in range(36):
# ----> 3         X[i][j]=fre[i][j]
#       4         Y_lifetime[i][j]=lifetime[i][j]
#       5         pass
#
# TypeError: 'numpy.complex128' object does not support item assignment

# %%
for i in range(455):
    for j in range(36):
        X[i][j]=float(fre[i][j])
        Y_lifetime[i][j]=float(lifetime[i][j])
        pass
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-f020d530c54c> in <module>
#       1 for i in range(455):
#       2     for j in range(36):
# ----> 3         X[i][j]=float(fre[i][j])
#       4         Y_lifetime[i][j]=float(lifetime[i][j])
#       5         pass
#
# TypeError: 'float' object does not support item assignment

# %%
fig=plt.figure()
for i in range(455):
    for j in range(35):
      X_plt = fre[i][j]
      Y_plt = lifetime[i][j]
      plt.plot(X_plt, Y_plt,color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     349             try:
# --> 350                 return self._range.index(new_key)
#     351             except ValueError:
#
# ValueError: 36 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-91d7b7e19627> in <module>
#       2 for i in range(455):
#       3     for j in range(35):
# ----> 4       X_plt = fre[i][j]
#       5       Y_plt = lifetime[i][j]
#       6       plt.plot(X_plt, Y_plt,color='red')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
# ...

# %%
fre[454,35]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: (454, 35)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-312a51c846ec> in <module>
# ----> 1 fre[454,35]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.10.2+cu113'

# %%
#定义向量
vector=torch.tensor([1,2,3,4])
print('vector:\t\t',vector)
print('vector shape:\t',vector.shape)
# Out:
# vector:		 tensor([1, 2, 3, 4])
# vector shape:	 torch.Size([4])

# %%
#定义矩阵
matrix=torch.tensor([[1,2],[3,4],[5,6]])
print('matrix:\n',matrix)
print('matrix shape: ',matrix.shape)
# Out:
# matrix:
#  tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# matrix shape:  torch.Size([3, 2])

# %%
#定义张量
tensor=torch.tensor([[[1,2],[3,4],[5,6]]])
print('tensor:\n',tensor)
print('tensor shape: ',tensor.shape)
# Out:
# tensor:
#  tensor([[[1, 2],
#          [3, 4],
#          [5, 6]]])
# tensor shape:  torch.Size([1, 3, 2])

# %%
cuda_gpu = torch.cuda.is_available()
cuda_gpu
# Out:
# True

# %%
x=torch.randn(10,30)
y=x.cuda()

# %%
import time
s=time.process_time()
z1=x**x**x
e=time.proces
# Out:
# tensor([[-0.0208,  1.0996,  0.7191,  0.0853,  0.1504,  0.6204,  0.2179,  0.8529,
#          -0.2139,  0.0652, -1.7631, -1.6472,  1.6476,  0.1303,  0.5188, -2.2594,
#           0.1286,  0.6053,  1.1105, -1.2827,  0.5461, -0.2827,  1.7098,  2.0514,
#           1.5674,  0.5944,  0.1240, -0.9329, -1.0201,  0.4281],
#         [-0.8391,  0.7199,  2.0180, -0.6904, -0.8868, -1.0570,  0.9727, -0.6638,
#          -0.3657, -1.6010,  0.6349,  1.0589,  0.0229,  1.1629,  0.1426, -0.9569,
#           0.1223,  0.9284, -0.4064,  0.5747, -0.7669, -1.4341,  0.5409, -1.4959,
#          -1.6521,  0.5461, -0.1674,  1.6404, -1.1822, -0.3221],
#         [ 0.1111, -1.0036,  0.0806, -1.5237,  1.2981, -1.8262, -0.9087, -0.3465,
#           0.8939, -0.6564,  1.1221, -0.2479,  0.0103, -0.6851, -0.8546, -1.4563,
#          -1.7524,  0.5312, -0.0319,  1.1147, -0.4101, -0.5613, -0.8868, -0.6989,
#           0.0153, -1.0088, -1.7626, -0.2513, -1.3266, -1.1498],
#         [-0.0214,  1.3606,  1.4271,  0.1374, -0.7359,  0.9356, -0.5350, -0.3466,
#           1.2875, -0.2734,  0.4395,  1.0427, -0.4409, -2.6441,  0.1743,  0.4532,
#          -0.9702,  0.6221, -1.0035,  0.4474, -0.5117,  0.8177, -0.2552, -0.4599,
#           0.0312,  1.1272,  1.0524, -0.2319,  1.3649,  1.4696],
#         [-0.9015,  0.5693,  1.0539, -1.9200,  0.7562, -0.6675, -1.9596, -0.3459,
#           0.7488,  0.5624,  2.3252,  2.5482, -0.8725,  0.2469,  0.6881,  0.5189,
#          -0.3159, -0.2120,  0.4874, -0.7871, -0.1484,  0.4058, -1.9362,  0.0760,
#          -0.5706, -0.1483, -0.8328, -0.1363, -0.3750,  0.7031],
#         [-0.7759, -2.2962, -0.5056, -0.7589,  0.7692, -0.2936,  1.8991,  1.8550,
#           1.1260,  0.3612,  0.7619,  0.6781,  0.2309,  1.3181,  0.8250,  1.7815,
#          -3.1620,  1.5382, -0.2639,  0.5454,  1.0462,  0.9645, -0.9344,  1.2663,
#           1.0248,  1.3519, -0.2476, -1.5753, -1.8538,  1.3123],
#         [-0.1843,  0.7528, -0.1724, -0.3898,  0.6686, -1.9587,  0.3943, -1.7070,
#           0.9435, -0.9644,  1.4666,  0.8838, -0.2812,  0.6591,  0.7767, -1.2519,
#          -0.5317, -0.3575,  0.0045, -0.4297,  1.3015, -0.9668,  1.5653, -0.0669,
#          -0.8370, -0.4325, -0.5865,  1.0769,  0.0045, -0.3577],
#         [-1.0137,  0.5686, -0.3868, -0.2940,  0.6659,  0.1359, -0.8620,  0.5675,
#          -0.8747, -0.4207, -1.1989,  1.3685, -0.5089,  1.1770, -1.1056,  1.5019,
#           1.2339, -0.3308,  0.6827,  0.6202, -0.9785, -1.3990,  1.2892, -0.9299,
#          -0.4996, -0.0472,  0.0975,  0.3814, -0.2709, -0.3690],
#         [-0.2402, -0.4074, -2.1502,  0.3761, -0.8244, -1.6174,  1.3715, -0.4915,
#          -1.6878, -0.2890,  0.2162,  0.6755,  1.0898,  0.4765,  0.1584, -0.1463,
#           0.6732,  1.7151, -0.2428,  0.1986, -1.2253, -0.0695,  0.4476, -1.4801,
#          -0.2822,  0.8538, -2.4061,  0.9919,  0.1005,  0.0485],
#         [-1.7918, -1.3376,  1.3648, -0.5344, -0.3660, -0.1129,  1.7454,  0.9136,
#          -0.3757, -0.5698, -0.1947, -0.8376,  1.1300,  0.3786,  0.3417,  0.9172,
#           0.6676,  0.3462,  0.2090,  0.1688,  0.8347,  1.9042,  2.1886,  1.1076,
#           0.1999, -0.5621, -0.0043, -0.9497,  1.2187,  0.4935]])
#  tensor([[-0.0208,  1.0996,  0.7191,  0.0853,  0.1504,  0.6204,  0.2179,  0.8529,
#          -0.2139,  0.0652, -1.7631, -1.6472,  1.6476,  0.1303,  0.5188, -2.2594,
#           0.1286,  0.6053,  1.1105, -1.2827,  0.5461, -0.2827,  1.7098,  2.0514,
#           1.5674,  0.5944,  0.1240, -0.9329, -1.0201,  0.4281],
#         [-0.8391,  0.7199,  2.0180, -0.6904, -0.8868, -1.0570,  0.9727, -0.6638,
#          -0.3657, -1.6010,  0.6349,  1.0589,  0.0229,  1.1629,  0.1426, -0.9569,
#           0.1223,  0.9284, -0.4064,  0.5747, -0.7669, -1.4341,  0.5409, -1.4959,
#          -1.6521,  0.5461, -0.1674,  1.6404, -1.1822, -0.3221],
#         [ 0.1111, -1.0036,  0.0806, -1.5237,  1.2981, -1.8262, -0.9087, -0.3465,
#           0.8939, -0.6564,  1.1221, -0.2479,  0.0103, -0.6851, -0.8546, -1.4563,
#          -1.7524,  0.5312, -0.0319,  1.1147, -0.4101, -0.5613, -0.8868, -0.6989,
#           0.0153, -1.0088, -1.7626, -0.2513, -1.3266, -1.1498],
#         [-0.0214,  1.3606,  1.4271,  0.1374, -0.7359,  0.9356, -0.5350, -0.3466,
#           1.2875, -0.2734,  0.4395,  1.0427, -0.4409, -2.6441,  0.1743,  0.4532,
#          -0.9702,  0.6221, -1.0035,  0.4474, -0.5117,  0.8177, -0.2552, -0.4599,
#           0.0312,  1.1272,  1.0524, -0.2319,  1.3649,  1.4696],
#         [-0.9015,  0.5693,  1.0539, -1.9200,  0.7562, -0.6675, -1.9596, -0.3459,
#           0.7488,  0.5624,  2.3252,  2.5482, -0.8725,  0.2469,  0.6881,  0.5189,
#          -0.3159, -0.2120,  0.4874, -0.7871, -0.1484,  0.4058, -1.9362,  0.0760,
#          -0.5706, -0.1483, -0.8328, -0.1363, -0.3750,  0.7031],
#         [-0.7759, -2.2962, -0.5056, -0.7589,  0.7692, -0.2936,  1.8991,  1.8550,
#           1.1260,  0.3612,  0.7619,  0.6781,  0.2309,  1.3181,  0.8250,  1.7815,
#          -3.1620,  1.5382, -0.2639,  0.5454,  1.0462,  0.9645, -0.9344,  1.2663,
#           1.0248,  1.3519, -0.2476, -1.5753, -1.8538,  1.3123],
#         [-0.1843,  0.7528, -0.1724, -0.3898,  0.6686, -1.9587,  0.3943, -1.7070,
#           0.9435, -0.9644,  1.4666,  0.8838, -0.2812,  0.6591,  0.7767, -1.2519,
#          -0.5317, -0.3575,  0.0045, -0.4297,  1.3015, -0.9668,  1.5653, -0.0669,
#          -0.8370, -0.4325, -0.5865,  1.0769,  0.0045, -0.3577],
#         [-1.0137,  0.5686, -0.3868, -0.2940,  0.6659,  0.1359, -0.8620,  0.5675,
#          -0.8747, -0.4207, -1.1989,  1.3685, -0.5089,  1.1770, -1.1056,  1.5019,
#           1.2339, -0.3308,  0.6827,  0.6202, -0.9785, -1.3990,  1.2892, -0.9299,
#          -0.4996, -0.0472,  0.0975,  0.3814, -0.2709, -0.3690],
#         [-0.2402, -0.4074, -2.1502,  0.3761, -0.8244, -1.6174,  1.3715, -0.4915,
#          -1.6878, -0.2890,  0.2162,  0.6755,  1.0898,  0.4765,  0.1584, -0.1463,
#           0.6732,  1.7151, -0.2428,  0.1986, -1.2253, -0.0695,  0.4476, -1.4801,
#          -0.2822,  0.8538, -2.4061,  0.9919,  0.1005,  0.0485],
#         [-1.7918, -1.3376,  1.3648, -0.5344, -0.3660, -0.1129,  1.7454,  0.9136,
#          -0.3757, -0.5698, -0.1947, -0.8376,  1.1300,  0.3786,  0.3417,  0.9172,
#           0.6676,  0.3462,  0.2090,  0.1688,  0.8347,  1.9042,  2.1886,  1.1076,
#           0.1999, -0.5621, -0.0043, -0.9497,  1.2187,  0.4935]],
#        device='cuda:0')

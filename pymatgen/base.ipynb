# %%
import pymatgen

# %%
POSCAR_path='D:\A研究生\computer_data\BiSeI\POSCAR'

# %%
from pymatgen.io.vasp import Poscar
poscar = Poscar.from_file(POSCAR_path)
structure = poscar.structure

# %%
structure
# Out:
# Structure Summary
# Lattice
#     abc : 8.704600021105904 4.2165279746556825 10.590763414698085
#  angles : 90.0 90.0 90.0
#  volume : 388.71479652948074
#       A : 8.704600021105904 0.0 0.0
#       B : 0.0 4.2165279746556825 0.0
#       C : 0.0 0.0 10.590763414698085
# PeriodicSite: Bi (7.5492, 1.0541, 6.6529) [0.8673, 0.2500, 0.6282]
# PeriodicSite: Bi (5.5077, 3.1624, 1.3576) [0.6327, 0.7500, 0.1282]
# PeriodicSite: Bi (1.1554, 3.1624, 3.9378) [0.1327, 0.7500, 0.3718]
# PeriodicSite: Bi (3.1969, 1.0541, 9.2332) [0.3673, 0.2500, 0.8718]
# PeriodicSite: Se (1.4868, 1.0541, 5.8573) [0.1708, 0.2500, 0.5531]
# PeriodicSite: Se (2.8655, 3.1624, 0.5620) [0.3292, 0.7500, 0.0531]
# PeriodicSite: Se (7.2178, 3.1624, 4.7334) [0.8292, 0.7500, 0.4469]
# PeriodicSite: Se (5.8391, 1.0541, 10.0288) [0.6708, 0.2500, 0.9469]
# PeriodicSite: I (0.1306, 3.1624, 8.7766) [0.0150, 0.7500, 0.8287]
# PeriodicSite: I (4.2217, 1.0541, 3.4812) [0.4850, 0.2500, 0.3287]
# ...

# %%
structure.get_distance(1,0)
# Out:
# 6.05420646922884

# %%
structure.as_dataframe()
# Out:
#    Species         a     b         c         x         y          z
# 0     (Bi)  0.867263  0.25  0.628183  7.549182  1.054132   6.652939
# 1     (Bi)  0.632737  0.75  0.128183  5.507718  3.162396   1.357557
# 2     (Bi)  0.132737  0.75  0.371817  1.155418  3.162396   3.937825
# 3     (Bi)  0.367263  0.25  0.871817  3.196882  1.054132   9.233207
# 4     (Se)  0.170812  0.25  0.553062  1.486849  1.054132   5.857350
# 5     (Se)  0.329188  0.75  0.053062  2.865451  3.162396   0.561968
# 6     (Se)  0.829188  0.75  0.446938  7.217751  3.162396   4.733413
# 7     (Se)  0.670812  0.25  0.946938  5.839149  1.054132  10.028795
# 8      (I)  0.014999  0.75  0.828705  0.130563  3.162396   8.776621
# 9      (I)  0.485001  0.25  0.328705  4.221737  1.054132   3.481240
# 10     (I)  0.985001  0.25  0.171295  8.574037  1.054132   1.814142
# 11     (I)  0.514999  0.75  0.671295  4.482863  3.162396   7.109524

# %%
structure.lattice
# Out:
# Lattice
#     abc : 8.704600021105904 4.2165279746556825 10.590763414698085
#  angles : 90.0 90.0 90.0
#  volume : 388.71479652948074
#       A : 8.704600021105904 0.0 0.0
#       B : 0.0 4.2165279746556825 0.0
#       C : 0.0 0.0 10.590763414698085

# %%
structure.distance_matrix
# Out:
# array([[0.        , 6.05420647, 4.14205101, 5.05967376, 2.7594449 ,
#         6.39220699, 2.87040057, 3.78425963, 3.25707768, 4.59690789,
#         4.94613792, 3.74907389],
#        [6.05420647, 0.        , 5.05967376, 4.14205101, 6.39220699,
#         2.7594449 , 3.78425963, 2.87040057, 4.59690789, 3.25707768,
#         3.74907389, 4.94613792],
#        [4.14205101, 5.05967376, 0.        , 6.05420647, 2.87040057,
#         3.78425963, 2.7594449 , 6.39220699, 4.94613792, 3.74907389,
#         3.25707768, 4.59690789],
#        [5.05967376, 4.14205101, 6.05420647, 0.        , 3.78425963,
#         2.87040057, 6.39220699, 2.7594449 , 3.74907389, 4.94613792,
#         4.59690789, 3.25707768],
#        [2.7594449 , 6.39220699, 2.87040057, 3.78425963, 0.        ,
#         5.86399101, 3.81456217, 6.02855461, 3.84791279, 3.62291505,
#         4.354716  , 3.87153978],
#        [6.39220699, 2.7594449 , 3.78425963, 2.87040057, 5.86399101,
# ...

# %%
structure.get_all_neighbors(3.)
# Out:
# [[PeriodicSite: Se (7.2178, -1.0541, 4.7334) [0.8292, -0.2500, 0.4469],
#   PeriodicSite: Se (7.2178, 3.1624, 4.7334) [0.8292, 0.7500, 0.4469],
#   PeriodicSite: Se (10.1914, 1.0541, 5.8573) [1.1708, 0.2500, 0.5531]],
#  [PeriodicSite: Se (2.8655, 3.1624, 0.5620) [0.3292, 0.7500, 0.0531],
#   PeriodicSite: Se (5.8391, 1.0541, -0.5620) [0.6708, 0.2500, -0.0531],
#   PeriodicSite: Se (5.8391, 5.2707, -0.5620) [0.6708, 1.2500, -0.0531]],
#  [PeriodicSite: Se (-1.4868, 3.1624, 4.7334) [-0.1708, 0.7500, 0.4469],
#   PeriodicSite: Se (1.4868, 1.0541, 5.8573) [0.1708, 0.2500, 0.5531],
#   PeriodicSite: Se (1.4868, 5.2707, 5.8573) [0.1708, 1.2500, 0.5531]],
#  [PeriodicSite: Se (2.8655, -1.0541, 11.1527) [0.3292, -0.2500, 1.0531],
#   PeriodicSite: Se (2.8655, 3.1624, 11.1527) [0.3292, 0.7500, 1.0531],
#   PeriodicSite: Se (5.8391, 1.0541, 10.0288) [0.6708, 0.2500, 0.9469]],
#  [PeriodicSite: Bi (-1.1554, 1.0541, 6.6529) [-0.1327, 0.2500, 0.6282],
# ...

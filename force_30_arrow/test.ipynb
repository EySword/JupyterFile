# %%
import pandas as pd
import numpy as np

# %%
f1=pd.read_table('forces.dat')

# %%
f1
# Out:
#        0.592642117382
# 0           -0.615709
# 1            0.137345
# 2            0.105870
# 3            0.009703
# 4           -0.092157
# ...               ...
# 61434        2.433677
# 61435       -0.260314
# 61436        1.043043
# 61437        0.212117
# 61438        0.718528
#
# [61439 rows x 1 columns]

# %%
f2=pd.read_table('forces_sf.dat',header=None,sep=' ')
f2
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-5fc9fe480224> in <module>
# ----> 1 f2=pd.read_table('forces_sf.dat',header=None,sep=' ')
#       2 f2
#
# D:\anaconda3\lib\site-packages\pandas\io\parsers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     687     kwds.update(kwds_defaults)
#     688
# ...

# %%
x=pd.DataFrame(np.loadtxt('forces_sf.dat'))

# %%
x
# Out:
#                  0         1         2         3         4         5   \
# 0     -3.354446e-12 -0.017493 -0.044638 -0.000319 -0.115997 -0.068845
# 1      8.901130e-12  0.019975  0.055357  0.000534  0.128332  0.097652
# 2      2.472485e-12 -0.003961 -0.021521  0.000069 -0.036480 -0.050921
# 3     -2.369237e-11 -0.005667  0.027657 -0.000912  0.015174  0.092868
# 4      7.877595e-12  0.001162 -0.006620  0.000333 -0.006187 -0.018020
# ...             ...       ...       ...       ...       ...       ...
# 61435 -1.772698e-08 -0.082583 -0.174156 -0.033239 -0.398295 -0.292821
# 61436  2.443177e-09  0.009909  0.039765  0.002660  0.084059  0.069270
# 61437 -6.699642e-10 -0.037671 -0.082531 -0.004791 -0.203148 -0.130105
# 61438 -9.321647e-10 -0.004927  0.022081 -0.003406  0.014592  0.063741
# 61439 -1.769059e-09 -0.017687 -0.008562 -0.007748 -0.044010  0.004776
#
#              6         7         8         9   ...        20        21  \
# ...

# %%
x=np.loadtxt('forces_sf.dat')
_y=np.loadtxt('forces.dat')
n=len(_y)
y=_y.reshape((n,1))

# %%
f2 = open('forces.dat')

# %%
f2.readline()
# Out:
# '0.592642117382\n'

# %%
f2.close()

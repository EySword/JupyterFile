# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
f=pd.read_csv('lec5-real-data.csv')

# %%
f
# Out:
#          year  month  permno         mvel1      beta    betasq     chmom  \
# 0        2000      1   10001  2.082500e+04  0.062785  0.003942  0.093899
# 1        2000      1   10002  9.419719e+04  0.487780  0.237929  0.026658
# 2        2000      1   10009  3.402825e+04  0.299169  0.089502 -0.093446
# 3        2000      1   10012  1.547943e+05  2.389908  5.711660  2.007230
# 4        2000      1   10016  3.372774e+05  0.619772  0.384117 -0.183942
# ...       ...    ...     ...           ...       ...       ...       ...
# 1310728  2016     12   93428  1.250976e+06  1.595315  2.545028 -0.137348
# 1310729  2016     12   93429  5.600537e+06  0.298267  0.088963  0.206434
# 1310730  2016     12   93433  2.473625e+04  2.324893  5.405128  0.328248
# 1310731  2016     12   93434  8.573280e+04  0.628519  0.395036  0.020854
# 1310732  2016     12   93436  2.840318e+07  1.588092  2.522036 -0.121017
#
#             dolvol   idiovol    indmom  ...  cashdebt     cashpr       cfp  \
# ...

# %%
f0=f.copy(deep=True)

# %%
id=list(f0.drop_duplicates(subset='permno', keep='first', inplace=False)['permno'])

# %%
mean=f0.mean()[3:]

# %%
median=f0.median()[3:]

# %%
std=f0.std()[3:]

# %%
perc=[f0.quantile(q=0.05)[3:],f0.quantile(q=0.25)[3:],f0.quantile(q=0.75)[3:],f0.quantile(q=0.95)[3:]]

# %%
meanYear={}
medianYear={}
stdYear={}
percYear={}
for i in range(2000,2017):
    f_data=f0[f0['year']==i]
    mean_each=f_data.mean()[3:]
    median_each=f_data.median()[3:]
    std_each=f_data.std()[3:]
    prec_each=[f_data.quantile(q=0.05)[3:],f_data.quantile(q=0.25)[3:],f_data.quantile(q=0.75)[3:],f_data.quantile(q=0.95)[3:]]
    meanYear[i]=mean_each
    medianYear[i]=median_each
    stdYear[i]=std_each
    percYear[i]=prec_each
    pass
